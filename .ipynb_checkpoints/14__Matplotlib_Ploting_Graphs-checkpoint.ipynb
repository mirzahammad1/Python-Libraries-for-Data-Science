# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Housing.csv')

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df = pd.read_csv('Housing.csv',parse_dates=['price'],index_col=['price'])

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#          area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 1750000  3850         3          1        2      yes        no       no
# 1750000  2910         3          1        1       no        no       no
# 1750000  3620         2          1        1      yes        no       no
# 1767150  2400         3          1        1       no        no       no
# 1820000  3000         2          1        1      yes        no      yes
#
#         hotwaterheating airconditioning  parking prefarea furnishingstatus
# price
# 1750000              no              no        0       no      unfurnished
# 1750000              no              no        0       no        furnished
# 1750000              no              no        0       no      unfurnished
# 1767150              no              no        0       no   semi-furnished
# 1820000              no              no        2       no      unfurnished

# %%
plt.plot(df['bedrooms'])

# %%
plt.boxplot(df['bedrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14a53f4c8d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14a54772ad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14a53c20310>],
#  'medians': [<matplotlib.lines.Line2D at 0x14a54804990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14a54805410>],
#  'means': []}

# %%
plt.hist(df['parking'])
# Out:
# (array([299.,   0.,   0., 126.,   0.,   0., 108.,   0.,   0.,  12.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('bedrooms')
plt.ylabel('parking')
plt.title('Scatter Plot')
plt.scatter(x=df['bedrooms'],y=df['parking'])

# %%
d={'a':18,'b':20,'c':13}

# %%
plt.bar(x=d.keys(),height=d.values())
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(x=d.values(),labels=d.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x14a58dac5d0>,
# ...
#  [Text(0.49031216423879204, 0.9846796339924332, 'a'),
#   Text(-1.0482361753702145, -0.3334680204235862, 'b'),
#   Text(0.7657474521900999, -0.7897030071263316, 'c')])

# %%
plt.plot(df['bedrooms'])

# %%
plt.figure(figsize=(15,10), dpi=100)
plt.xlabel('bedrooms')
plt.ylabel('bathrooms')
plt.legend()
plt.plot(df['bathrooms'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(15,10), dpi=100)
plt.xlabel('bedrooms')
plt.ylabel('bathrooms')
plt.legend()
plt.plot(df['bathrooms'])
plt.savefig('Bathrooms.png')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
